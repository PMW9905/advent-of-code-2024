# %% [markdown]
# Let's get the input values for the test

# %%
inputString = "..."
newString = "2333133121414131402"
print(inputString);
# Out:
# ...

# %%
#lets get the count of total elements
elementCount = len(inputString)
print(elementCount)
# Out:
# 19999

# %%
#Now I want to get a set of the ID's and the whitespace sizes

idSpaceList = []
emptySpaceList = []
dictList = []
curId = 0
x = 0
samplearr = []
idList = []
visArr = []
totalsize = 0;
for element in inputString:
    if x % 2 != 0:
        idSpaceList.append(element)
        for num in range(int(element)):
            visArr.append(".")
            emptySpaceList.append(".")
        dictList.append({"id": curId, "length": element, "index": totalsize})
        totalsize = totalsize + int(element);
    if x % 2 == 0:
        emptySpaceList.append(element)
        for num in range(int(element)):
            visArr.append(curId)
            idList.append(curId)
        dictList.append({"id": curId, "length": element, "index": totalsize})
        totalsize = totalsize + int(element);
        curId = curId + 1
    x = x+1

    
print(len(visArr))
currentIndex = 0
reverseIdList = []
idCount = len(idList) - 1
while idCount > 0:
    reverseIdList.append(idList[idCount])
    idCount = idCount - 1;
newList = []
inputArr = visArr
print(str(len(reverseIdList)+ 1))
print(str(len(emptySpaceList)))
reverseIndex = 0

j = 0
lastId = 0
lastIter = False
for value in visArr:
    if int(reverseIdList[reverseIndex]) >= int(lastId):
        if len(newList) < len(reverseIdList)+ 1:
            if value != ".":
                    newList.append(value)
                    lastId = value
            if value == ".":
                    newList.append(reverseIdList[reverseIndex])
                    reverseIndex = reverseIndex + 1
            currentIndex = currentIndex + 1

print(totalsize)
print(newList)
finalValue = 0
checksum = 0
for value in newList:
    product = finalValue * value
    checksum = checksum + product
    finalValue = finalValue + 1

print(str(checksum))
# Out:
# 95674
# 50083
# 55591
# 95674
# ...

# %%
#This is all testing 

startingIdNum = len(idSpaceList) - 1
currentLastId = len(dictList) - 1
actualIndex = 0
currentRecord = dictList[0]

#we want to alternate between the empty space calcuations
#and the id space calculations
#so will keep a current index counter,
#when the current index matches the size -1
#we switch array's that we are working with
totalLeft = 0
checksum = 0
indexarr = []

print(len(dictList))
finalIter = False
for y in range(len(dictList)):
            if finalIter == False:
                if y == 0: 
                    totalLeft = int(dictList[currentLastId].get("length")) - 1;
                    currentNumber = int(dictList[currentLastId].get("id"));
                if y % 2 == 0:
                    size = dictList[y].get("length")
                    dictId = dictList[y].get("id")
                    for z in range(int(size)):
                        product = actualIndex * dictId
                        checksum = checksum + product
                        indexarr.append(dictId)
                        actualIndex = actualIndex + 1
                    #do the Id value multiplying and adding
                if y % 2 != 0:
                    if dictId != currentLastId:
                        size = dictList[y].get("length")
                        for z in range(int(size)):
                            if dictId != currentLastId:
                                    if totalLeft <= 0:
                                        if actualIndex < int(dictList[currentLastId].get("index")):
                                            currentLastId = currentLastId - 1
                                            totalLeft = int(dictList[currentLastId].get("length")) - 1;
                                            currentNumber = int(dictList[currentLastId].get("id"));
                                    product = actualIndex * currentNumber
                                    checksum = checksum + product
                                    indexarr.append(currentNumber)
                                    actualIndex = actualIndex + 1
                                    totalLeft = totalLeft - 1
                            if dictId == currentLastId:
                                while actualIndex <= int(dictList[currentLastId].get("index")):
                                    print(str(remainingSpots));
                                    if remaningSpots < totalLeft:
                                        while remaningSpots > 0:
                                            product = actualIndex * currentNumber
                                            checksum = checksum + product
                                            indexarr.append(currentNumber)
                                            actualIndex = actualIndex + 1
                                            remaningSpots = remaningSpots - 1
                                            totalLeft = totalLeft - 1
                                            
                                        while totalLeft > 0:
                                            print("totaleft1")
                                            product = actualIndex * currentNumber
                                            checksum = checksum + product
                                            indexarr.append(currentNumber)
                                            actualIndex = actualIndex + 1
                                            totalLeft = totalLeft - 1
                                        if totalLeft == 0:
                                            print("FINAL CHECKSUM VALUE IS : " + str(checksum))
                                        
                                else:
                                    while totalLeft > 0:
                                        print("ttoalleft2")
                                        product = actualIndex * currentNumber
                                        checksum = checksum + product
                                        indexarr.append(currentNumber)
                                        actualIndex = actualIndex + 1
                                        totalLeft = totalLeft - 1
                                    if totalLeft == 0:
                                        print("FINAL CHECKSUM VALUE IS : " + str(checksum))
                    if actualIndex >= int(dictList[currentLastId].get("index")):
                        print("ran out of characters, value is " + str(checksum))
                    curId = curId + 1
                    if actualIndex >= int(dictList[currentLastId].get("index")):
                        finalIter = True
                    else:
                        finalIter = False
            else:
               print("Current Index: " + str(actualIndex)) 
               print("Current Index start for Id:" + str(int(dictList[currentLastId].get("index"))))
               if actualIndex == int(dictList[currentLastId].get("index")):
                   product = actualIndex * int(dictList[currentLastId].get("id"))
                   checksum = checksum + product
               print("Final CheckSum: " + str(checksum))
               break
                    
print("total math count " + str(y))
print(str(checksum))
def getIdSum(currentId, size):
    
    return totalProduct

def getFillerSums(maxId, maxIdCount, size):
    totalProduct = 0;
    for x in range(size):
        newValues.append(currentId)
        print("GetEmptySum: " + currentId + " * " +  actualId + " " + " = " + (currentId * actualIndex))
        totalProduct = totalProduct + (currentId * actualIndex)
        actualIndex = actualIndex + 1
    return totalProduct
# Out:
# 19999
# ran out of characters, value is 10733935769071
# Current Index: 60757
# Current Index start for Id:60751
# Final CheckSum: 10733935769071
# total math count 12676
# 10733935769071
